# %%
import pandas as pd
from pathlib import Path

# %%
data_dir = Path('../data/')
print(data_dir)
# Out:
# ..\data

# %%
df = pd.read_csv(Path.joinpath(data_dir, "Cincy311_2022_final.tsv"),delimiter="\t")
df.shape
# Out:
# (114922, 16)

# %%
df
# Out:
#        SERVICE_REQUEST_ID STATUS                      SERVICE_NAME  \
# 0              SR21000495   OPEN           "Building, residential"
# 1              SR21001191    NEW           "Building, residential"
# 2              SR21001193    NEW           "Building, residential"
# 3              SR21001047    NEW           "Building, residential"
# 4              SR21000753   OPEN           "Building, residential"
# ...                   ...    ...                               ...
# 114917         SR22105088   CLOS  "Metal Furniture, Spec Collectn"
# 114918         SR22105031   CLOS  "Metal Furniture, Spec Collectn"
# 114919         SR22105163   CLOS  "Metal Furniture, Spec Collectn"
# 114920         SR22104953   CLOS  "Metal Furniture, Spec Collectn"
# 114921         SR22105255   CLOS  "Metal Furniture, Spec Collectn"
#
#        SERVICE_CODE                                        DESCRIPTION  \
# 0         "BLD-RES"  "Request entered through the Web. Refer to Int...
# ...

# %%
df.SERVICE_REQUEST_ID.sort_values(axis=0)
# Out:
# 90204                instantly transferred to yard waste!""
# 27445                                                    ""
# 17756                                                    ""
# 22217                                                    ""
# 716                                                      ""
#                                 ...
# 41395                                             unit #2""
# 113244    utility sink is unclean (Im told this was issu...
# 88038                         will not collect next week ""
# 14432                                                you.""
# 99057     ·         Martin Luther King Dr., at Highland,...
# Name: SERVICE_REQUEST_ID, Length: 114922, dtype: object
