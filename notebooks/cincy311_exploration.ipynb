# %%
import pandas as pd
from pathlib import Path

# %%
data_dir = Path('../data/')
print(data_dir)
# Out:
# ..\data

# %%
df = pd.read_csv(Path.joinpath(data_dir, "Cincy311_cleaned.tsv"),delimiter="|")
df.shape
# Out:
# (104747, 15)

# %%
df
# Out:
#        status                      service_name service_code  \
# 0         NEW  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 1         NEW                   "Default, City"   "DFLTCITY"
# 2         NEW                 "Pothole, repair"     "PTHOLE"
# 3         NEW   "Dumping, prv prop <2500 sq ft"   "DUMP-PVS"
# 4         NEW     "Parking, grass front yd res"   "PRKNGYRD"
# ...       ...                               ...          ...
# 104742   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104743   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104744   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104745   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104746   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
#
#                                               description  agency_responsible  \
# 0       "Request entered through the Web. Refer to Int...     Public Services
# ...

# %%
df[(pd.to_datetime(df.updated_date) - pd.to_datetime(df.requested_date)).dt.days != 0]
# Out:
#        status                      service_name service_code  \
# 374      CLOS        "Litter, private property"   "LITR-PRV"
# 375      OPEN           "Building, residential"    "BLD-RES"
# 406      CLOS  "Tree, removal request-pub tree"   "CPARKF-C"
# 425      CLOS     "Parking, grass front yd res"   "PRKNGYRD"
# 426      CLOS     "Roaches - bldg or apartment"    "ROACHES"
# ...       ...                               ...          ...
# 104742   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104743   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104744   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104745   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
# 104746   CLOS  "Metal Furniture, Spec Collectn"    "MTL-FRN"
#
#                                               description  agency_responsible  \
# 374     "Request entered through the Web. Refer to Int...     Public Services
# ...
