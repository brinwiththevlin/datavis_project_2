# %%
import pandas as pd
from pathlib import Path

# %%
# raw_csv_path = Path("..\data\Cincinnati_311__Non-Emergency__Service_Requests.csv")
# provided_tvs_path = Path("..\data\Cincy311_2022_final.tsv", delimiter="\t")
site_df = pd.read_csv(Path("../data/cincy311_cleaned.tsv"),sep="|")
# site_df = pd.read_csv(raw_csv_path)

site_df.columns
# Out:
# Index(['service_request_id', 'status', 'service_name', 'service_code',
#        'description', 'agency_responsible', 'requested_datetime',
#        'updated_datetime', 'expected_datetime', 'address', 'zipcode',
#        'latitude', 'longitude', 'requested_date', 'updated_date',
#        'last_table_update'],
#       dtype='object')

# %%
site_df.columns = list(map(str.lower,site_df.columns))
site_df
# Out:
#        service_request_id status                      service_name  \
# 0              SR21103031    NEW           "Building, residential"
# 1              SR21103214    NEW           "Building, residential"
# 2              SR21103056    NEW             "Plumbing, defective"
# 3              SR21103261   PEND    "Sign, handicap parking signs"
# 4              SR21103248    NEW     "Food operation, request gen"
# ...                   ...    ...                               ...
# 114950         SR22105111   CLOS  "Metal Furniture, Spec Collectn"
# 114951         SR22105088   CLOS  "Metal Furniture, Spec Collectn"
# 114952         SR22105031   CLOS  "Metal Furniture, Spec Collectn"
# 114953         SR22105255   CLOS  "Metal Furniture, Spec Collectn"
# 114954         SR22104953   CLOS  "Metal Furniture, Spec Collectn"
#
#        service_code                                        description  \
# 0         "BLD-RES"  "MOLD AND BATHROOM SMELLS LIKE SEWEGE\r\nTHESE...
# 1         "BLD-RES"              "Issue existing orders to new owner."
# 2        "PLMB_DEF"    " 2ND FL BATHRMN LEAKING INTO 1ST CAUSING MOLD"
# 3        "HNDCPPRK"                        "Requesting handicap sign "
# 4        "GRCRYCNC"                         "McDonald's- Bugs in tea."
# ...             ...                                                ...
# 114950    "MTL-FRN"                                                " "
# 114951    "MTL-FRN"                                                " "
# 114952    "MTL-FRN"  "Request entered through the Web. Refer to Int...
# 114953    "MTL-FRN"  "Request entered through the Web. Refer to Int...
# 114954    "MTL-FRN"  "Request entered through the Web. Refer to Int...
#
#            agency_responsible requested_datetime updated_datetime  \
# 0          Cinc Building Dept         2021-12-06       2021-12-06
# 1          Cinc Building Dept         2021-12-06       2021-12-06
# 2            Cinc Health Dept         2021-12-06       2021-12-06
# 3       Dept of Trans and Eng         2021-12-06       2021-12-06
# 4            Cinc Health Dept         2021-12-06       2021-12-06
# ...                       ...                ...              ...
# 114950        Public Services         2022-12-01       2023-01-12
# 114951        Public Services         2022-12-01       2023-01-12
# 114952        Public Services         2022-12-01       2023-01-12
# 114953        Public Services         2022-12-01       2023-01-17
# 114954        Public Services         2022-11-30       2023-01-13
#
#        expected_datetime                                    address  zipcode  \
# 0             2022-12-06           "2001 SUNSET LN - GJ0930433614 "  45238.0
# 1             2022-12-06         "3107 COLERAIN AV - GJ1272435237 "  45225.0
# 2             2022-06-04         "843 DELEHANTY CT - GJ0782331779 "  45238.0
# 3             2022-06-04          "4450 EASTERN AV - GJ2284032530 "  45226.0
# 4             2022-06-04          "5341 GLENWAY AV - GJ0696433597 "  45238.0
# ...                  ...                                        ...      ...
# 114950        2022-12-15          "5498 STEWART AV - GJ2493538464 "  45227.0
# 114951        2022-12-15            "537 SUTTON RD - GJ2421527002 "  45230.0
# 114952        2022-12-15      "1015 PAXTON AV, CINC - GJ2170734325"  45208.0
# 114953        2022-12-15   "790 E MITCHELL AV, CINC - GJ1726337276"  45229.0
# 114954        2022-12-14  "3303 AMELIAMONT AV, CINC - GJ2264636232"  45209.0
#
#          latitude  longitude          requested_date            updated_date  \
# 0       39.126569 -84.578697  12/06/2021 12:00:00 AM  12/06/2021 12:00:00 AM
# 1       39.140355 -84.538651  12/06/2021 12:00:00 AM  12/06/2021 12:00:00 AM
# 2       39.110404 -84.596371  12/06/2021 12:00:00 AM  12/06/2021 12:00:00 AM
# 3       39.113450 -84.422603  12/06/2021 12:00:00 AM  12/06/2021 12:00:00 AM
# 4       39.126973 -84.605747  12/06/2021 12:00:00 AM  12/06/2021 12:00:00 AM
# ...           ...        ...                     ...                     ...
# 114950  39.166329 -84.396430  12/01/2022 12:00:00 AM  01/12/2023 12:00:00 AM
# 114951  39.063337 -84.408535  12/01/2022 12:00:00 AM  01/12/2023 12:00:00 AM
# 114952  39.129906 -84.435094  12/01/2022 12:00:00 AM  01/12/2023 12:00:00 AM
# 114953  39.157590 -84.485519  12/01/2022 12:00:00 AM  01/17/2023 12:00:00 AM
# 114954  39.146830 -84.423625  11/30/2022 12:00:00 AM  01/13/2023 12:00:00 AM
#
#              last_table_update
# 0       12/06/2021 12:00:00 AM
# 1       12/06/2021 12:00:00 AM
# 2       12/06/2021 12:00:00 AM
# 3       12/06/2021 12:00:00 AM
# 4       12/06/2021 12:00:00 AM
# ...                        ...
# 114950  01/12/2023 12:00:00 AM
# 114951  01/12/2023 12:00:00 AM
# 114952  01/12/2023 12:00:00 AM
# 114953  01/17/2023 12:00:00 AM
# 114954  01/13/2023 12:00:00 AM
#
# [114955 rows x 16 columns]

# %%
new_df = site_df[site_df.requested_datetime.str[:4] == "2022"]
len(new_df)
# Out:
# 104747

# %%
site_df.to_csv("../data/cincy311_cleaned.tsv", sep="|", index=False)

# %%
from pprint import pprint
pprint(new_df.service_code.unique().tolist())
# Out:
# ['"MTL-FRN"',
#  '"DFLTCITY"',
#  '"PTHOLE"',
#  '"DUMP-PVS"',
#  '"PRKNGYRD"',
#  '"SCLEN1"',
#  '"YDWSTA-J"',
#  '"ABAN-VNA"',
#  '"DAPUB1"',
#  '"TRREPR"',
#  '"RF-COLLT"',
#  '"LITR-PRV"',
#  '"GRFITI"',
#  '"SWAP96"',
#  '"TIRES"',
#  '"TRASH-I"',
#  '"DFLTPLC"',
#  '"RCYCLNG"',
#  '"PLMB_DEF"',
#  '"NEW96CRT"',
#  '"TRSHCRTR"',
#  '"MSSNGPRP"',
#  '"BLD-RES"',
#  '"SIDWLKH"',
#  '"TGGDCLLC"',
#  '"STRTLITE"',
#  '"MICE-BLD"',
#  '"DMGTROD"',
#  '"REPAIR64"',
#  '"MOLD"',
#  '"TRSHCITE"',
#  '"TSIG-MAL"',
#  '"NW/MSSNG"',
#  '"REPAIR96"',
#  '"YRDWSTTC"',
#  '"RECCINFO"',
#  '"NEW64CRT"',
#  '"SVCCMPLT"',
#  '"TRSHNTRL"',
#  '"HNDCPPRK"',
#  '"STRSGN"',
#  '"ABAN-VPR"',
#  '"CNTRCTR"',
#  '"ROACHES"',
#  '"SEWAG_EX"',
#  '"BD_UNSAN"',
#  '"TLGR-PRB"',
#  '"SLPYST"',
#  '"CAN-DAMG"',
#  '"SWGTSDOP"',
#  '"NEW35CRT"',
#  '"CRNRCNOF"',
#  '"BLD-COM"',
#  '"SGNDNA"',
#  '"STRTPLTM"',
#  '"OPENBURN"',
#  '"STTSRVC"',
#  '"CITYCONI"',
#  '"WTRLKSBK"',
#  '"TREEPR"',
#  '"TLGR-PRV"',
#  '"TLGR-PS"',
#  '"FIRESPCL"',
#  '"CPARKF-C"',
#  '"LGHT,NWS"',
#  '"HEAT"',
#  '"RCNEWLIC"',
#  '"MSSNGSTR"',
#  '"MLDCHLDR"',
#  '"ADASDWKO"',
#  '"FDSRVCUN"',
#  '"NLTSCLG"',
#  '"ANNUALC"',
#  '"STRTPLTC"',
#  '"RATS"',
#  '"RCHSCHLR"',
#  '"ODOT"',
#  '"SCARACCS"',
#  '"SPDHMPS"',
#  '"TRSHONAR"',
#  '"RTSCHLDR"',
#  '"CLEAN-ST"',
#  '"MNHLCVRM"',
#  '"FRHYDRNT"',
#  '"RWFRNTRT"',
#  '"LTRSTPNH"',
#  '"SRVCMPLT"',
#  '"CRNCAN-N"',
#  '"TRASH-L"',
#  '"SRVCMPSC"',
#  '"REMOVE"',
#  '"ADACALTP"',
#  '"WTR_NO"',
#  '"BLKYTMST"',
#  '"BLD_VACR"',
#  '"STRRPRG"',
#  '"BLDCNPR"',
#  '"TREESPLT"',
#  '"RSTRNTRC"',
#  '"SWAP64"',
#  '"SGNL,TRF"',
#  '"TPLANT"',
#  '"BLDUNSR"',
#  '"RTNNGWLL"',
#  '"SVCCMPLY"',
#  '"TPAMANDR"',
#  '"FENCMTLC"',
#  '"DFLTDOTE"',
#  '"PRKNGMTR"',
#  '"TRSHRQNS"',
#  '"NEW18CRT"',
#  '"REPLCE64"',
#  '"GRCRYCNC"',
#  '"BLD_VACC"',
#  '"NCRHMNT,"',
#  '"CONTAMRE"',
#  '"TRSHREMV"',
#  '"TRASH-E"',
#  '"TDWNLDUF"',
#  '"CAVEIMSD"',
#  '"SLPYST-H"',
#  '"PAVMK"',
#  '"BLD_COLL"',
#  '"SRVCMPLR"',
#  '"CHNGFLSH"',
#  '"STERMOVR"',
#  '"BNCHS,DT"',
#  '"DFLTACCS"',
#  '"TIRESRTC"',
#  '"SNKNRRP"',
#  '"CRNCAN-D"',
#  '"DMGNOD"',
#  '"RWTRDMPN"',
#  '"MTL-FRNS"',
#  '"SWAP35"',
#  '"LTSTT"',
#  '"BLD_USER"',
#  '"TRMISS65"',
#  '"DFLTMSD"',
#  '"NW-MSSNG"',
#  '"SRVCCPRU"',
#  '"SIGN_ZC"',
#  '"ZONCCER"',
#  '"HLSDSP"',
#  '"AWNING"',
#  '"PLAYPARK"',
#  '"BDBGSRQ"',
#  '"DOG_WSTE"',
#  '"RLCTNRQS"',
#  '"VACANT"',
#  '"AMNESTYL"',
#  '"FDBRNLLN"',
#  '"VDRPRCW"',
#  '"TRTRIMUF"',
#  '"TRNEW65"',
#  '"SGNSHPNI"',
#  '"WASTECMP"',
#  '"DMPSTR-H"',
#  '"ADACBRMP"',
#  '"LTTR-PRB"',
#  '"SPILL-N1"',
#  '"STERMNOI"',
#  '"TRSHCNCD"',
#  '"SMOKEDET"',
#  '"FLSNPRTB"',
#  '"BLD_BAR"',
#  '"FENC-REP"',
#  '"BARRIC"',
#  '"STSGN"',
#  '"USE_R"',
#  '"ILLHOMEC"',
#  '"REPLCE96"',
#  '"WTRPNDNG"',
#  '"DDNML,PR"',
#  '"TLGR-BLD"',
#  '"REPAIR35"',
#  '"NWGRDRL"',
#  '"SCARCRIM"',
#  '"CAG_PPDV"',
#  '"DFLTPARK"',
#  '"TRSHCRTE"',
#  '"GUARDR"',
#  '"BLDRRFIF"',
#  '"DMGCLM"',
#  '"DFLTMSDS"',
#  '"BLD-ELVP"',
#  '"BDOVCRDR"',
#  '"SIGNREMV"',
#  '"NFRMTNRQ"',
#  '"BLD-ELEH"',
#  '"SCH_MOLD"',
#  '"RTSNSWR"',
#  '"WDSBSTRC"',
#  '"RSTRNTIE"',
#  '"MUD"',
#  '"FDBRNCMP"',
#  '"THORN-UF"',
#  '"SDWLK,NW"',
#  '"STLPLTS,"',
#  '"STERMURU"',
#  '"STRRPR"',
#  '"DFLTPRKG"',
#  '"DFLTCWW"',
#  '"SIGNFREE"',
#  '"RCNBTSRM"',
#  '"SCHLANNL"',
#  '"CURBREP"',
#  '"SPHLTCMP"',
#  '"SRVCOMG"',
#  '"ZONCCE"',
#  '"BLD_RFIC"',
#  '"HOMEOWNI"',
#  '"PARKINGC"',
#  '"IN-CLSPD"',
#  '"NSTTTNRM"',
#  '"NW/CHNGV"',
#  '"RQSTNGHB"',
#  '"SCOMPLSC"',
#  '"TTRMPVUF"',
#  '"CAFESRSP"',
#  '"MDDVSWNO"',
#  '"BLD-ELIC"',
#  '"RSTRNTIC"',
#  '"LTTR-PRK"',
#  '"BKRCKRQS"',
#  '"SGNL_TNW"',
#  '"SGNVRHD"',
#  '"FOOD_RES"',
#  '"DFLTRCR"',
#  '"HLSDSP-H"',
#  '"OTHERRSP"',
#  '"UNSANHOT"',
#  '"STERMPRK"',
#  '"USE_C"',
#  '"GRAFPARK"',
#  '"SGNL,TNW"',
#  '"BLDNOPC"',
#  '"DNS-IN"',
#  '"VOID-REP"',
#  '"BLDFRESC"',
#  '"LIGHTSIH"',
#  '"TLGR-DTE"',
#  '"LTTR-REC"',
#  '"STRTHVD"',
#  '"STORGHOT"',
#  '"LGHT,TSN"',
#  '"LANDMPS"',
#  '"VFLSHFIL"',
#  '"MSQTSPN"',
#  '"EXIT_B"',
#  '"GYMSHSW"',
#  '"FENCLINR"',
#  '"YRD-WSTE"',
#  '"FRHYDNTR"',
#  '"REPLCE18"',
#  '"PLANTERS"',
#  '"PAVEMARK"',
#  '"FENCMTLR"',
#  '"TSTUMPUF"',
#  '"BDBGHOTL"',
#  '"LTTR-HLT"',
#  '"NWTRFFCS"',
#  '"CBHDSS"',
#  '"6MNTHNSP"',
#  '"NMPRVDST"',
#  '"PDSTLLGH"',
#  '"LOT_VACE"',
#  '"TRSBLCKS"',
#  '"CAG_CSRM"',
#  '"CTZNCMPL"',
#  '"FRDRLCK"',
#  '"SRVCCMPL"',
#  '"SRVCPLCS"',
#  '"BLD-DUNS"',
#  '"SCARSCLN"',
#  '"BLD_USEC"',
#  '"MDDVSRY"',
#  '"HIKEPARK"',
#  '"RLRDSCOM"',
#  '"LRWLIGHT"',
#  '"SYVCCMPL"',
#  '"ERC_PV"',
#  '"DRNKPARK"',
#  '"SRVCMPCS"',
#  '"TLGR-REC"',
#  '"BLDPLH"',
#  '"RSTRTN,T"',
#  '"STERMBHV"',
#  '"BLDFRFAC"',
#  '"HTS-STP"',
#  '"LANDSLDE"',
#  '"TLGR-PRK"',
#  '"HANDRL"',
#  '"BCYCOBST"',
#  '"PLMB HAZ"',
#  '"REPLCE35"',
#  '"PAVERS"',
#  '"RDNTHOTL"',
#  '"AN_WASTE"',
#  '"CBHBBE"',
#  '"TRSHPARK"',
#  '"SWAP18"',
#  '"RECSRVCP"',
#  '"LTTR-BLD"',
#  '"BCYCRACK"',
#  '"BLD-DCOR"',
#  '"VHCLPRGS"',
#  '"TRFFCSLN"',
#  '"TRBV-UF"',
#  '"FACTPARK"',
#  '"RATSOUT"',
#  '"LIGHTSIB"',
#  '"BRDG,PTH"',
#  '"LTTR-CDV"',
#  '"TRBVPRUF"',
#  '"ADACONSN"',
#  '"LTTR-POL"',
#  '"SCARPOOR"',
#  '"UTILASPH"',
#  '"FREPREVI"',
#  '"TREEPARK"',
#  '"VD,DTNST"',
#  '"BEAUPARK"',
#  '"SIGN_ZR"',
#  '"SCH_PLMB"',
#  '"BCYCLSTN"',
#  '"PRKNMTRR"',
#  '"SPDHMPS,"',
#  '"STERMSAF"',
#  '"LTTR-PFC"',
#  '"SCREGELM"',
#  '"SCH_ROAC"',
#  '"BLD-DISV"',
#  '"STERMDES"',
#  '"LIFESAFF"',
#  '"SRVCPLGS"',
#  '"IASSESSM"',
#  '"AAADACCC"',
#  '"NMLBTRP"',
#  '"LTTRRST"',
#  '"TRREPR65"',
#  '"TRASH-RE"',
#  '"TRREPR95"',
#  '"POTHPARK"',
#  '"PLMB PV"',
#  '"LGHTPARK"',
#  '"GCWW_INQ"',
#  '"WASPPARK"',
#  '"BCYCLABN"',
#  '"BENCHES"',
#  '"STERMUNS"',
#  '"BUSSTRSP"',
#  '"INTERM"',
#  '"BLDUNSC"',
#  '"BLD-RCO"',
#  '"SGN_TNW"',
#  '"SGNSHPNE"',
#  '"MIDDLE"',
#  '"HOMEOWNF"',
#  '"SIGNOPLE"',
#  '"LNDSLP"',
#  '"TLGR-CDP"',
#  '"TLGR-HLT"',
#  '"DBLSGNL"',
#  '"PLCJUNKV"',
#  '"CLG-INLT"',
#  '"SRVCMPLC"',
#  '"ELECNOPW"',
#  '"GRFITI-H"',
#  '"ATTNRP"',
#  '"AARANACC"',
#  '"SVCCMPWW"',
#  '"BLDCRFIF"',
#  '"HIGH"',
#  '"SCH_GNRL"',
#  '"BARRIC-H"',
#  '"SCHLCFTC"',
#  '"LTTR-CWW"',
#  '"RCYCLNSR"',
#  '"TMPRRYRP"',
#  '"BUSFMRES"',
#  '"FDOOR_MD"',
#  '"PVMTPRDR"',
#  '"CNSTRCTN"',
#  '"PRIVUTAB"']
